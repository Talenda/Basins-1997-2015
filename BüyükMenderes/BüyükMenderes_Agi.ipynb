# %%
import pandas as pd

# %% [markdown]
# [Hex Color Codes](https://htmlcolorcodes.com/)

# %% [markdown]
# # <center><font color = "#40E0D0">Büyük Menderes <font><center>

# %%
place = "C:/Users/user/Desktop/$Main_Tübitak/DSI_Uniform_Output/Buyuk_Menderes/"
stations= pd.read_excel(place +"FlowBook_Buyuk_Menderes_Basin_1997_Station_Info.xlsx")
stations
# Out:
#     Unnamed: 0   stname      area     elev       east      north
# 0            0  D07A003   2015.00   837.00  29.800000  38.333333
# 1            1  D07A004   2957.00   814.00  29.800000  38.216667
# 2            2  D07A007    974.00   273.00  29.200000  37.816667
# 3            3  D07A008    265.00   290.00  29.216667  37.816667
# 4            4  D07A010    295.70   841.00  30.100000  38.116667
# 5            5  D07A015     54.00   231.15  27.850000  42.100000
# 6            6  D07A026    293.00   841.00  30.100000  38.116667
# 7            7  D07A030     96.06   177.00  28.050000  38.900000
# 8            8  D07A032  14193.00    69.00  28.316667  37.883333
# 9            9  D07A035   1462.00   152.00  28.133333  37.500000
# 10          10  D07A039     90.50    73.00  27.616667  37.883333
# 11          11  D07A052    275.60   980.00  29.989444  38.505000
# 12          12  D07A053    100.00   829.00  29.850000  38.316667
# 13          13  D07A059   1726.00   160.00  29.050000  37.916667
# 14          14  D07A061    589.80   199.38  28.600000  37.800000
# 15          15  D07A062  22653.00    17.00  27.700000  37.816667
# 16          16  D07A065   9006.00   307.00  29.200000  38.133333
# 17          17  D07A071   4203.00   758.00  29.433333  38.050000
# 18          18  D07A075    215.30  1010.00  30.201111  38.120000
# 19          19  D07A079    123.00   365.00  28.100000  37.300000
# 20          20  D07A081  11852.00   130.00  26.916667  37.950000
# 21          21  D07A082    184.00  1110.00  28.033333  37.750000
# 22          22  D07A083    668.30   855.00  28.916667  37.583333
# 23          23  D07A087     46.20  1067.00  30.075833  38.388889
# 24          24  D07A093     34.50     0.00  28.800000  37.700000
# 25          25  D07A096     41.00   450.00  28.133333  37.250000
# 26          26  D07A097     70.00   425.00  28.200000  37.333333
# 27          27  D07A098     30.00   500.00  28.250000  37.283333
# 28          28  D07A099     63.00   395.00  28.200000  37.300000
# 29          29  D07A100     63.50   336.00  28.000000  37.400000
# 30          30  D07A102     40.00   640.00  28.733333  37.750000
# 31          31  D07A103    212.00    15.00  27.533333  37.716667
# 32          32  D07A107     37.50     0.00  27.733333  37.883333
# 33          33  D07A108     30.00   160.00  27.533333  37.566667
# 34          34  D07A109     41.80   120.00  27.700000  37.900000
# 35          35  D07A111     36.00  1067.00  30.080556  38.381944
# 36          36  D07A114     87.30   140.00  28.383333  37.616667

# %%
for i in range(1998,2016):
    xdata =pd.read_excel(place +f"FlowBook_Buyuk_Menderes_Basin_{i}_Station_Info.xlsx.")
    stations = pd.concat([stations, xdata])

# %%
stations
# Out:
#     Unnamed: 0   stname    area   elev       east      north
# 0            0  D07A003  2015.0  837.0  29.800000  38.333333
# 1            1  D07A004  2957.0  814.0  29.800000  38.216667
# 2            2  D07A007   974.0  273.0  29.200000  37.816667
# 3            3  D07A008   265.0  290.0  29.216667  37.816667
# 4            4  D07A010   295.7  841.0  30.100000  38.116667
# ..         ...      ...     ...    ...        ...        ...
# 40          40  E07A037   169.7  478.0  28.615556  37.261944
# 41          41  E07A038   100.1  132.0  28.025000  37.907500
# 42          42  E07A042  2285.5  531.0  29.306389  38.373056
# 43          43  E07A043  9731.0  176.0  29.005278  38.078889
# 44          44  E07A044   411.0  855.0  28.962778  37.558889
#
# [568 rows x 6 columns]

# %%
stations["stname"].value_counts()
# Out:
# D07A100    19
# D07A075    18
# D07A093    17
# D07A079    17
# D07A103    16
#            ..
# D07A035     2
# D07A132     2
# D07A134     2
# E07A034     1
# D07A102     1
# Name: stname, Length: 69, dtype: int64

# %%
stations = stations.drop_duplicates(subset="stname")

# %%
stations
# Out:
#     Unnamed: 0   stname     area    elev       east      north
# 0            0  D07A003  2015.00   837.0  29.800000  38.333333
# 1            1  D07A004  2957.00   814.0  29.800000  38.216667
# 2            2  D07A007   974.00   273.0  29.200000  37.816667
# 3            3  D07A008   265.00   290.0  29.216667  37.816667
# 4            4  D07A010   295.70   841.0  30.100000  38.116667
# ..         ...      ...      ...     ...        ...        ...
# 44          44  E07A044   411.00   855.0  28.962778  37.558889
# 7            7  D07A070  3810.00    55.0  28.314444  37.812778
# 32          32  D07A131  1560.00    69.0  28.064722  37.543333
# 28          28  D07A132    26.90     NaN  29.765278  38.841389
# 29          29  D07A134    54.98  1150.0  29.525833  37.647500
#
# [69 rows x 6 columns]

# %%
del stations["Unnamed: 0"]

# %%
stations
# Out:
#      stname     area    elev       east      north
# 0   D07A003  2015.00   837.0  29.800000  38.333333
# 1   D07A004  2957.00   814.0  29.800000  38.216667
# 2   D07A007   974.00   273.0  29.200000  37.816667
# 3   D07A008   265.00   290.0  29.216667  37.816667
# 4   D07A010   295.70   841.0  30.100000  38.116667
# ..      ...      ...     ...        ...        ...
# 44  E07A044   411.00   855.0  28.962778  37.558889
# 7   D07A070  3810.00    55.0  28.314444  37.812778
# 32  D07A131  1560.00    69.0  28.064722  37.543333
# 28  D07A132    26.90     NaN  29.765278  38.841389
# 29  D07A134    54.98  1150.0  29.525833  37.647500
#
# [69 rows x 5 columns]

# %%
stations.to_excel("Stations_BuyukMenderes.xlsx")

# %%
stations.to_csv("Stations_BuyukMenderes.csv")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ## <center><font color= "#8E44AD">Only stations <font><center>

# %%
station_name = stations["stname"].drop_duplicates()

# %%
station_name
# Out:
# 0     D07A003
# 1     D07A004
# 2     D07A007
# 3     D07A008
# 4     D07A010
#        ...
# 44    E07A044
# 7     D07A070
# 32    D07A131
# 28    D07A132
# 29    D07A134
# Name: stname, Length: 69, dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">BüyükMenderes_DSİ_Data<font><center>

# %%
stations = pd.read_excel('Stations_BuyukMenderes.xlsx', index_col=0)
df_total = pd.DataFrame(columns = stations.stname)

for i in range(1997,2016):
    x= pd.read_excel(place +f"FlowBook_Buyuk_Menderes_Basin_{i}_FlowTimeSeries.xlsx")
    df_total = pd.concat([df_total, x])

# %%
df_total.set_index("datetime", inplace=True)

# %%
df_total.to_excel("Agi_BuyukMenderes_1997-2015.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Null Count<font><center>

# %%
df_total.isnull().sum().sort_values(ascending=False)
# Out:
# D07A102    6574
# E07A034    6573
# D07A134    6356
# D07A132    6332
# D07A053    6209
#            ...
# D07A093     731
# D07A079     730
# D07A075     365
# D07A100       0
# data          0
# Length: 70, dtype: int64

# %%
lis=list(df_total.isnull().sum())

# %%
stations["null"]= 101

# %%
for i in range(len(stations["stname"])):
    stations["null"].iloc[i]=lis[i]
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
stations
# Out:
#      stname     area    elev       east      north  null
# 0   D07A003  2015.00   837.0  29.800000  38.333333  2191
# 1   D07A004  2957.00   814.0  29.800000  38.216667  4017
# 2   D07A007   974.00   273.0  29.200000  37.816667  3651
# 3   D07A008   265.00   290.0  29.216667  37.816667  2973
# 4   D07A010   295.70   841.0  30.100000  38.116667  2191
# ..      ...      ...     ...        ...        ...   ...
# 44  E07A044   411.00   855.0  28.962778  37.558889  5478
# 7   D07A070  3810.00    55.0  28.314444  37.812778  5844
# 32  D07A131  1560.00    69.0  28.064722  37.543333  5844
# 28  D07A132    26.90     NaN  29.765278  38.841389  6332
# 29  D07A134    54.98  1150.0  29.525833  37.647500  6356
#
# [69 rows x 6 columns]

# %%
stations.to_excel("Null_BuyukMenderes.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Hydrograph<font><center>

# %%
import matplotlib.pyplot as plt
from matplotlib import dates as mdates

# %%
hg_agi=df_total

# %%
#Graph with months
for i in range(len(stations.stname)):
    plt=hg_agi[stations.stname.iloc[i]].plot(kind='line',label=f'{stations.stname.iloc[i]}_agi',color= 'blue',figsize=(15,5))
    plt.set_ylabel('Discharge')
    plt.set_xlabel('Time')
    # Minor ticks every month.
    fmt_month = mdates.MonthLocator()
    # Minor ticks every year.
    fmt_year = mdates.YearLocator()
    plt.xaxis.set_minor_locator(fmt_month)
    # '%b' to get the names of the month
    # '%m' to get months as number
    plt.xaxis.set_minor_formatter(mdates.DateFormatter('%m'))
    plt.xaxis.set_major_locator(fmt_year)
    plt.xaxis.set_major_formatter(mdates.DateFormatter('%m'))

    # fontsize for month labels
    plt.tick_params(labelsize=8, which='both')
    # create a second x-axis beneath the first x-axis to show the year in YYYY format
    sec_xaxis = plt.secondary_xaxis(-0.1)
    sec_xaxis.xaxis.set_major_locator(fmt_year)
    sec_xaxis.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.set_xlabel('Time')

    ##start, end = plt.get_xlim()
    ##plt.xaxis.set_ticks(np.arange(start, end))
    plt.grid(zorder=0,linestyle='dotted', color='black')
    plt.patch.set_facecolor('#D7ABEF')
    plt.legend()
    plt.get_figure().savefig(f"Plot_BuyukMenderes/{stations.stname.iloc[i]}.png",bbox_inches='tight',facecolor="#D7ABEF")
    plt.cla()
    # Blue for agi, orange for efas data
