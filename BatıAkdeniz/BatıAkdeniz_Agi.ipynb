# 42          42  D08A124   680.40   100.00  30.236111  36.428333
# 43          43  D08A126     9.53  1685.00  29.886944  36.896667

# %%
for i in range(1998,2016):
    xdata =pd.read_excel(place +f"FlowBook_Bati_Akdeniz_Basin_{i}_Station_Info.xlsx.")
    stations = pd.concat([stations, xdata])

# %%
stations
# Out:
#     Unnamed: 0   stname    area    elev       east      north
# 0            0  D08A009  3280.0   815.0  29.333333  37.316667
# 1            1  D08A018   126.2  1091.0  29.666944  37.217778
# 2            2  D08A019   145.0    66.0  27.833333  37.333333
# 3            3  D08A028  2461.0     9.0  29.316667  36.366667
# 4            4  D08A049   222.2   208.0  30.116667  36.450000
# ..         ...      ...     ...     ...        ...        ...
# 42          42  E08A008   770.0   342.0  30.074444  36.490833
# 43          43  E08A009   546.8  1115.0  29.561944  36.825278
# 44          44  E08A011  3890.6   595.0  29.103333  37.093889
# 45          45  E08A015  2448.0     8.0  29.316667  36.356389
# 46          46  E08A018   234.1   110.0  29.403333  36.473333
#
# [696 rows x 6 columns]

# %%
stations["stname"].value_counts()
# Out:
# D08A018    19
# D08A103    19
# D08A100    19
# D08A061    19
# D08A067    19
#            ..
# D08A090     2
# D08A060     1
# D08A131     1
# D08A151     1
# D08A157     1
# Name: stname, Length: 78, dtype: int64

# %%
stations = stations.drop_duplicates(subset="stname")

# %%
stations
# Out:
#     Unnamed: 0   stname     area    elev       east      north
# 0            0  D08A009  3280.00   815.0  29.333333  37.316667
# 1            1  D08A018   126.20  1091.0  29.666944  37.217778
# 2            2  D08A019   145.00    66.0  27.833333  37.333333
# 3            3  D08A028  2461.00     9.0  29.316667  36.366667
# 4            4  D08A049   222.20   208.0  30.116667  36.450000
# ..         ...      ...      ...     ...        ...        ...
# 35          35  D08A155    11.10    38.0  27.671111  37.196944
# 36          36  D08A156   802.00   196.0  29.387222  36.747500
# 39          39  D08A160    45.50   137.0  28.600833  37.073333
# 34          34  D08A151  5152.50    37.0  28.794167  36.834167
# 40          40  D08A157    29.14  1210.0  30.008889  36.870000
#
# [78 rows x 6 columns]

# %%
del stations["Unnamed: 0"]

# %%
stations.to_excel("Stations_BatıAkdeniz.xlsx")

# %%
stations.to_csv("Stations_BatıAkdeniz.csv")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ## <center><font color= "#8E44AD">Only stations <font><center>

# %%
station_name = stations["stname"].drop_duplicates()

# %%
station_name
# Out:
# 0     D08A009
# 1     D08A018
# 2     D08A019
# 3     D08A028
# 4     D08A049
#        ...
# 35    D08A155
# 36    D08A156
# 39    D08A160
# 34    D08A151
# 40    D08A157
# Name: stname, Length: 78, dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">BatıAkdeniz_DSİ_Data<font><center>

# %%
stations = pd.read_excel('Stations_BatıAkdeniz.xlsx', index_col=0)
df_total = pd.DataFrame(columns = stations.stname)

for i in range(1997,2016):
    x= pd.read_excel(place +f"FlowBook_Bati_Akdeniz_Basin_{i}_FlowTimeSeries.xlsx")
    df_total = pd.concat([df_total, x])

# %%
df_total.set_index("datetime", inplace=True)

# %%
df_total.to_excel("Agi_BatıAkdeniz_1997-2015.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Null Count<font><center>

# %%
df_total.isnull().sum().sort_values(ascending=False)
# Out:
# D08A131    6574
# D08A157    6574
# D08A151    6574
# D08A060    6574
# D08A160    6354
#            ...
# D08A083       0
# D08A070       0
# D08A067       0
# D08A061       0
# data          0
# Length: 79, dtype: int64

# %%
lis=list(df_total.isnull().sum())

# %%
stations["null"]= 101

# %%
for i in range(len(stations["stname"])):
    stations["null"].iloc[i]=lis[i]
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
stations
# Out:
#      stname     area    elev       east      north  null
# 0   D08A009  3280.00   815.0  29.333333  37.316667   365
# 1   D08A018   126.20  1091.0  29.666944  37.217778     0
# 2   D08A019   145.00    66.0  27.833333  37.333333  4383
# 3   D08A028  2461.00     9.0  29.316667  36.366667  6209
# 4   D08A049   222.20   208.0  30.116667  36.450000   730
# ..      ...      ...     ...        ...        ...   ...
# 35  D08A155    11.10    38.0  27.671111  37.196944  5844
# 36  D08A156   802.00   196.0  29.387222  36.747500  5844
# 39  D08A160    45.50   137.0  28.600833  37.073333  6354
# 34  D08A151  5152.50    37.0  28.794167  36.834167  6574
# 40  D08A157    29.14  1210.0  30.008889  36.870000  6574
#
# [78 rows x 6 columns]

# %%
stations.to_excel("Null_BatıAkdeniz.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Hydrograph<font><center>

# %%
import matplotlib.pyplot as plt
from matplotlib import dates as mdates

# %%
hg_agi=df_total

# %%
#Graph with months
for i in range(len(stations.stname)):
    plt=hg_agi[stations.stname.iloc[i]].plot(kind='line',label=f'{stations.stname.iloc[i]}_agi',color= 'blue',figsize=(15,5))
    plt.set_ylabel('Discharge')
    plt.set_xlabel('Time')
    # Minor ticks every month.
    fmt_month = mdates.MonthLocator()
    # Minor ticks every year.
    fmt_year = mdates.YearLocator()
    plt.xaxis.set_minor_locator(fmt_month)
    # '%b' to get the names of the month
    # '%m' to get months as number
    plt.xaxis.set_minor_formatter(mdates.DateFormatter('%m'))
    plt.xaxis.set_major_locator(fmt_year)
    plt.xaxis.set_major_formatter(mdates.DateFormatter('%m'))

    # fontsize for month labels
    plt.tick_params(labelsize=8, which='both')
    # create a second x-axis beneath the first x-axis to show the year in YYYY format
    sec_xaxis = plt.secondary_xaxis(-0.1)
    sec_xaxis.xaxis.set_major_locator(fmt_year)
    sec_xaxis.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.set_xlabel('Time')

    ##start, end = plt.get_xlim()
    ##plt.xaxis.set_ticks(np.arange(start, end))
    plt.grid(zorder=0,linestyle='dotted', color='black')
    plt.patch.set_facecolor('#9BEEDF')
    plt.legend()
    plt.get_figure().savefig(f"Plot_BatıAkdeniz/{stations.stname.iloc[i]}.png",bbox_inches='tight',facecolor="#9BEEDF")
    plt.cla()
    # Blue for agi, orange for efas data
