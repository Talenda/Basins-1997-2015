# %%
import pandas as pd

# %% [markdown]
# [Hex Color Codes](https://htmlcolorcodes.com/)

# %% [markdown]
# # <center><font color = "#40E0D0">Doğu Akdeniz <font><center>

# %%
place = "C:/Users/user/Desktop/$Main_Tübitak/DSI_Uniform_Output/Dogu_Akdeniz/"
stations= pd.read_excel(place +"FlowBook_Dogu_Akdeniz_Basin_1997_Station_Info.xlsx")
stations
# Out:
#     Unnamed: 0   stname     area  elev       east      north
# 0            0  D17A007   599.00   132  34.768333  37.030556
# 1            1  D17A011   410.00   125  34.553056  36.861667
# 2            2  D17A012   156.40  1297  33.916111  36.761944
# 3            3  D17A014  2156.00   509  32.950000  36.550000
# 4            4  D17A016  2994.00   233  33.187778  36.781667
# 5            5  D17A017   364.00  1241  32.300000  37.116667
# 6            6  D17A024   194.00   160  33.536944  36.236667
# 7            7  D17A027   134.00    60  32.354167  36.326111
# 8            8  D17A029    22.00   100  32.916389  36.188611
# 9            9  D17A031    90.00   850  34.501389  36.150000
# 10          10  D17A032    27.93    80  32.716667  36.116667
# 11          11  D17A033   588.40   850  32.600000  37.050000
# 12          12  D17A035   491.00   925  32.533333  36.966667
# 13          13  D17A037    42.00   325  34.275278  36.689722
# 14          14  D17A038   158.00    35  32.216111  36.445000
# 15          15  D17A039   139.34    56  32.375556  36.288889
# 16          16  D17A040   380.00   125  34.254167  36.656389
# 17          17  D17A041   324.80    20  32.983333  29.600000
# 18          18  D17A043   265.00   560  34.810278  37.161944
# 19          19  D17A045    67.00   460  34.440278  36.891111

# %%
for i in range(1998,2016):
    xdata =pd.read_excel(place +f"FlowBook_Dogu_Akdeniz_Basin_{i}_Station_Info.xlsx.")
    stations = pd.concat([stations, xdata])

# %%
stations
# Out:
#     Unnamed: 0   stname    area  elev       east      north
# 0            0  D17A007   599.0   132  34.768333  37.030556
# 1            1  D17A011   410.0   125  34.553056  36.861667
# 2            2  D17A012   156.4  1297  33.916111  36.761944
# 3            3  D17A014  2156.0   509  32.950000  36.550000
# 4            4  D17A016  2994.0   233  33.187778  36.781667
# ..         ...      ...     ...   ...        ...        ...
# 31          31  E17A033   217.6   730  34.639167  37.225556
# 32          32  E17A038   109.8   960  32.810000  36.976389
# 33          33  E17A039   159.8   590  34.333611  36.865000
# 34          34  E17A041   311.7  1180  32.450833  36.690833
# 35          35  E17A042   903.2   723  32.681111  36.568611
#
# [489 rows x 6 columns]

# %%
stations["stname"].value_counts()
# Out:
# D17A007    19
# D17A012    19
# D17A016    19
# D17A024    19
# D17A027    19
# D17A039    19
# D17A033    18
# D17A011    18
# D17A034    18
# D17A035    18
# D17A038    18
# D17A040    17
# D17A017    16
# D17A047    16
# D17A045    15
# D17A050    15
# D17A046    15
# D17A049    15
# D17A006    14
# D17A044    14
# D17A051    13
# D17A041    12
# D17A053    12
# D17A054    11
# D17A043    11
# D17A014    11
# D17A029     9
# D17A037     7
# D17A048     5
# D17A031     5
# E17A039     4
# D17A055     4
# E17A014     4
# E17A020     4
# E17A021     4
# E17A025     4
# E17A033     4
# E17A029     3
# E17A012     3
# E17A017     3
# E17A041     2
# E17A038     2
# D17A056     2
# D17A042     2
# D17A036     2
# E17A037     1
# E17A032     1
# E17A030     1
# D17A032     1
# E17A042     1
# Name: stname, dtype: int64

# %%
stations = stations.drop_duplicates(subset="stname")

# %%
stations
# Out:
#     Unnamed: 0   stname      area  elev       east      north
# 0            0  D17A007    599.00   132  34.768333  37.030556
# 1            1  D17A011    410.00   125  34.553056  36.861667
# 2            2  D17A012    156.40  1297  33.916111  36.761944
# 3            3  D17A014   2156.00   509  32.950000  36.550000
# 4            4  D17A016   2994.00   233  33.187778  36.781667
# 5            5  D17A017    364.00  1241  32.300000  37.116667
# 6            6  D17A024    194.00   160  33.536944  36.236667
# 7            7  D17A027    134.00    60  32.354167  36.326111
# 8            8  D17A029     22.00   100  32.916389  36.188611
# 9            9  D17A031     90.00   850  34.501389  36.150000
# 10          10  D17A032     27.93    80  32.716667  36.116667
# 11          11  D17A033    588.40   850  32.600000  37.050000
# 12          12  D17A035    491.00   925  32.533333  36.966667
# 13          13  D17A037     42.00   325  34.275278  36.689722
# 14          14  D17A038    158.00    35  32.216111  36.445000
# 15          15  D17A039    139.34    56  32.375556  36.288889
# 16          16  D17A040    380.00   125  34.254167  36.656389
# 17          17  D17A041    324.80    20  32.983333  29.600000
# 18          18  D17A043    265.00   560  34.810278  37.161944
# 19          19  D17A045     67.00   460  34.440278  36.891111
# 11          11  D17A034     68.00  1075  32.533333  36.950000
# 13          13  D17A036     31.00   120  34.746667  36.973056
# 18          18  D17A042   1000.00     0   0.000000   0.000000
# 20          20  D17A046    268.80  1200  34.161667  36.837500
# 21          21  D17A047     91.10  1500  33.894444  36.829167
# 22          22  D17A048      0.00     0   0.000000   0.000000
# 23          23  D17A050   1026.00   480  34.108056  36.616111
# 0            0  D17A006    331.00   130  34.690833  36.963056
# 19          19  D17A044     31.80    15  33.295278  36.138333
# 23          23  D17A049   1356.00    10  34.226111  36.575833
# 20          20  D17A051    502.00   180  36.446389  36.715278
# 24          24  D17A053   9765.00    58  33.645556  36.441944
# 23          23  D17A054    340.00   615  34.531111  37.120833
# 24          24  D17A055     78.90   328  34.323611  36.741944
# 25          25  E17A012   2689.20   397  33.025833  36.635278
# 26          26  E17A014  10065.20    24  33.815556  36.403611
# 27          27  E17A020   4304.00   127  33.369444  36.635833
# 28          28  E17A021    313.20    37  32.895556  36.175833
# 29          29  E17A025    203.00  1031  32.656667  36.615556
# 30          30  E17A029      9.50   635  32.778333  36.316667
# 31          31  E17A030     60.00   225  32.813889  36.262500
# 32          32  E17A032    301.00   443  34.722778  37.164722
# 33          33  E17A033    217.60   730  34.639167  37.225556
# 34          34  E17A037    706.80   230  33.599167  36.581111
# 35          35  E17A039    159.80   590  34.333611  36.865000
# 27          28  E17A017   1005.20   975  34.005556  36.660000
# 26          26  D17A056    134.50   118  32.602778  36.158611
# 35          35  E17A038    109.80   960  32.810000  36.976389
# 37          37  E17A041    311.70  1180  32.450833  36.690833
# 35          35  E17A042    903.20   723  32.681111  36.568611

# %%
del stations["Unnamed: 0"]

# %%
stations.to_excel("Stations_DoğuAkdeniz.xlsx")

# %%
stations.to_csv("Stations_DoğuAkdeniz.csv")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ## <center><font color= "#8E44AD">Only stations <font><center>

# %%
station_name = stations["stname"].drop_duplicates()

# %%
station_name
# Out:
# 0     D17A007
# 1     D17A011
# 2     D17A012
# 3     D17A014
# 4     D17A016
# 5     D17A017
# 6     D17A024
# 7     D17A027
# 8     D17A029
# 9     D17A031
# 10    D17A032
# 11    D17A033
# 12    D17A035
# 13    D17A037
# 14    D17A038
# 15    D17A039
# 16    D17A040
# 17    D17A041
# 18    D17A043
# 19    D17A045
# 11    D17A034
# 13    D17A036
# 18    D17A042
# 20    D17A046
# 21    D17A047
# 22    D17A048
# 23    D17A050
# 0     D17A006
# 19    D17A044
# 23    D17A049
# 20    D17A051
# 24    D17A053
# 23    D17A054
# 24    D17A055
# 25    E17A012
# 26    E17A014
# 27    E17A020
# 28    E17A021
# 29    E17A025
# 30    E17A029
# 31    E17A030
# 32    E17A032
# 33    E17A033
# 34    E17A037
# 35    E17A039
# 27    E17A017
# 26    D17A056
# 35    E17A038
# 37    E17A041
# 35    E17A042
# Name: stname, dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">DoğuAkdeniz_DSİ_Data<font><center>

# %%
stations = pd.read_excel('Stations_DoğuAkdeniz.xlsx', index_col=0)
df_total = pd.DataFrame(columns = stations.stname)

for i in range(1997,2016):
    x= pd.read_excel(place +f"FlowBook_Dogu_Akdeniz_Basin_{i}_FlowTimeSeries.xlsx")
    df_total = pd.concat([df_total, x])

# %%
df_total.set_index("datetime", inplace=True)

# %%
df_total.to_excel("Agi_DoğuAkdeniz_1997-2015.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Null Count<font><center>

# %%
df_total.isnull().sum().sort_values(ascending=False)
# Out:
# E17A042    6574
# D17A032    6574
# E17A037    6573
# E17A032    6573
# E17A030    6573
# D17A042    6209
# D17A056    6209
# E17A041    6209
# E17A038    6209
# D17A036    6209
# E17A012    5844
# E17A017    5844
# E17A029    5843
# E17A021    5478
# E17A020    5478
# E17A014    5478
# E17A025    5478
# E17A033    5478
# D17A055    5478
# E17A039    5478
# D17A048    5113
# D17A031    5113
# D17A037    4382
# D17A029    3652
# D17A014    2922
# D17A054    2922
# D17A043    2921
# D17A041    2557
# D17A053    2556
# D17A051    2191
# D17A044    1825
# D17A006    1825
# D17A050    1461
# D17A046    1461
# D17A045    1461
# D17A049    1460
# D17A017    1096
# D17A047    1095
# D17A040     731
# D17A035     503
# D17A034     426
# D17A033     426
# D17A011     365
# D17A038     365
# D17A024       8
# D17A007       0
# D17A039       0
# D17A027       0
# D17A016       0
# D17A012       0
# data          0
# dtype: int64

# %%
lis=list(df_total.isnull().sum())

# %%
stations["null"]= 101

# %%
for i in range(len(stations["stname"])):
    stations["null"].iloc[i]=lis[i]
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
stations
# Out:
#      stname      area  elev       east      north  null
# 0   D17A007    599.00   132  34.768333  37.030556     0
# 1   D17A011    410.00   125  34.553056  36.861667   365
# 2   D17A012    156.40  1297  33.916111  36.761944     0
# 3   D17A014   2156.00   509  32.950000  36.550000  2922
# 4   D17A016   2994.00   233  33.187778  36.781667     0
# 5   D17A017    364.00  1241  32.300000  37.116667  1096
# 6   D17A024    194.00   160  33.536944  36.236667     8
# 7   D17A027    134.00    60  32.354167  36.326111     0
# 8   D17A029     22.00   100  32.916389  36.188611  3652
# 9   D17A031     90.00   850  34.501389  36.150000  5113
# 10  D17A032     27.93    80  32.716667  36.116667  6574
# 11  D17A033    588.40   850  32.600000  37.050000   426
# 12  D17A035    491.00   925  32.533333  36.966667   503
# 13  D17A037     42.00   325  34.275278  36.689722  4382
# 14  D17A038    158.00    35  32.216111  36.445000   365
# 15  D17A039    139.34    56  32.375556  36.288889     0
# 16  D17A040    380.00   125  34.254167  36.656389   731
# 17  D17A041    324.80    20  32.983333  29.600000  2557
# 18  D17A043    265.00   560  34.810278  37.161944  2921
# 19  D17A045     67.00   460  34.440278  36.891111  1461
# 11  D17A034     68.00  1075  32.533333  36.950000   426
# 13  D17A036     31.00   120  34.746667  36.973056  6209
# 18  D17A042   1000.00     0   0.000000   0.000000  6209
# 20  D17A046    268.80  1200  34.161667  36.837500  1461
# 21  D17A047     91.10  1500  33.894444  36.829167  1095
# 22  D17A048      0.00     0   0.000000   0.000000  5113
# 23  D17A050   1026.00   480  34.108056  36.616111  1461
# 0   D17A006    331.00   130  34.690833  36.963056  1825
# 19  D17A044     31.80    15  33.295278  36.138333  1825
# 23  D17A049   1356.00    10  34.226111  36.575833  1460
# 20  D17A051    502.00   180  36.446389  36.715278  2191
# 24  D17A053   9765.00    58  33.645556  36.441944  2556
# 23  D17A054    340.00   615  34.531111  37.120833  2922
# 24  D17A055     78.90   328  34.323611  36.741944  5478
# 25  E17A012   2689.20   397  33.025833  36.635278  5844
# 26  E17A014  10065.20    24  33.815556  36.403611  5478
# 27  E17A020   4304.00   127  33.369444  36.635833  5478
# 28  E17A021    313.20    37  32.895556  36.175833  5478
# 29  E17A025    203.00  1031  32.656667  36.615556  5478
# 30  E17A029      9.50   635  32.778333  36.316667  5843
# 31  E17A030     60.00   225  32.813889  36.262500  6573
# 32  E17A032    301.00   443  34.722778  37.164722  6573
# 33  E17A033    217.60   730  34.639167  37.225556  5478
# 34  E17A037    706.80   230  33.599167  36.581111  6573
# 35  E17A039    159.80   590  34.333611  36.865000  5478
# 27  E17A017   1005.20   975  34.005556  36.660000  5844
# 26  D17A056    134.50   118  32.602778  36.158611  6209
# 35  E17A038    109.80   960  32.810000  36.976389  6209
# 37  E17A041    311.70  1180  32.450833  36.690833  6209
# 35  E17A042    903.20   723  32.681111  36.568611  6574

# %%
stations.to_excel("Null_DoğuAkdeniz.xlsx")

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # <center><font color= "red">Hydrograph<font><center>

# %%
import matplotlib.pyplot as plt
from matplotlib import dates as mdates

# %%
hg_agi=df_total

# %%
#Graph with months
for i in range(len(stations.stname)):
    plt=hg_agi[stations.stname.iloc[i]].plot(kind='line',label=f'{stations.stname.iloc[i]}_agi',color= 'blue',figsize=(15,5))
    plt.set_ylabel('Discharge')
    plt.set_xlabel('Time')
    # Minor ticks every month.
    fmt_month = mdates.MonthLocator()
    # Minor ticks every year.
    fmt_year = mdates.YearLocator()
    plt.xaxis.set_minor_locator(fmt_month)
    # '%b' to get the names of the month
    # '%m' to get months as number
    plt.xaxis.set_minor_formatter(mdates.DateFormatter('%m'))
    plt.xaxis.set_major_locator(fmt_year)
    plt.xaxis.set_major_formatter(mdates.DateFormatter('%m'))

    # fontsize for month labels
    plt.tick_params(labelsize=8, which='both')
    # create a second x-axis beneath the first x-axis to show the year in YYYY format
    sec_xaxis = plt.secondary_xaxis(-0.1)
    sec_xaxis.xaxis.set_major_locator(fmt_year)
    sec_xaxis.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.set_xlabel('Time')

    ##start, end = plt.get_xlim()
    ##plt.xaxis.set_ticks(np.arange(start, end))
    plt.grid(zorder=0,linestyle='dotted', color='black')
    plt.patch.set_facecolor('#EEEBB0')
    plt.legend()
    plt.get_figure().savefig(f"Plot_DoğuAkdeniz/{stations.stname.iloc[i]}.png",bbox_inches='tight',facecolor="#EEEBB0")
    plt.cla()
    # Blue for agi, orange for efas data
